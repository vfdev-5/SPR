# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %pylab inline
pylab.rcParams['figure.figsize'] = (10, 6)
color = sns.color_palette()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
TARGET_LABELS = ['ind_ahor_fin_ult1', 'ind_aval_fin_ult1', 'ind_cco_fin_ult1',
 'ind_cder_fin_ult1', 'ind_cno_fin_ult1', 'ind_ctju_fin_ult1',
 'ind_ctma_fin_ult1', 'ind_ctop_fin_ult1', 'ind_ctpp_fin_ult1',
 'ind_deco_fin_ult1', 'ind_deme_fin_ult1', 'ind_dela_fin_ult1',
 'ind_ecue_fin_ult1', 'ind_fond_fin_ult1', 'ind_hip_fin_ult1',
 'ind_plan_fin_ult1', 'ind_pres_fin_ult1', 'ind_reca_fin_ult1',
 'ind_tjcr_fin_ult1', 'ind_valo_fin_ult1', 'ind_viv_fin_ult1',
 'ind_nomina_ult1', 'ind_nom_pens_ult1', 'ind_recibo_ult1']

# %% [markdown]
# Load data : 06/2015 and 07/2015

# %%
data_path = "data/"

# %%
train_month_06 = pd.read_csv(data_path+"train_2015-6.csv")
train_month_07 = pd.read_csv(data_path+"train_2015-7.csv")
# Out:
# /home/osboxes/Documents/TDS/venv/local/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# Number of clients :

# %%
print len(train_month_06['ncodpers'].unique()), len(train_month_07['ncodpers'].unique())
# Out:
# 630244 829811

# %%
print train_month_06[TARGET_LABELS].sum().sum(), train_month_07[TARGET_LABELS].sum().sum()
# Out:
# 1130726.0 1147954

# %%
train_month_06[TARGET_LABELS].describe()
# Out:
#        ind_ahor_fin_ult1  ind_aval_fin_ult1  ind_cco_fin_ult1  \
# count      630244.000000      630244.000000     630244.000000
# mean            0.000132           0.000033          0.783828
# std             0.011475           0.005772          0.411633
# min             0.000000           0.000000          0.000000
# 25%             0.000000           0.000000          1.000000
# 50%             0.000000           0.000000          1.000000
# 75%             0.000000           0.000000          1.000000
# max             1.000000           1.000000          1.000000
#
#        ind_cder_fin_ult1  ind_cno_fin_ult1  ind_ctju_fin_ult1  \
# count      630244.000000     630244.000000      630244.000000
# mean            0.000501          0.094951           0.012051
# std             0.022386          0.293147           0.109113
# min             0.000000          0.000000           0.000000
# 25%             0.000000          0.000000           0.000000
# 50%             0.000000          0.000000           0.000000
# 75%             0.000000          0.000000           0.000000
# max             1.000000          1.000000           1.000000
#
#        ind_ctma_fin_ult1  ind_ctop_fin_ult1  ind_ctpp_fin_ult1  \
# count      630244.000000      630244.000000      630244.000000
# mean            0.010980           0.165967           0.056077
# std             0.104208           0.372052           0.230070
# min             0.000000           0.000000           0.000000
# 25%             0.000000           0.000000           0.000000
# 50%             0.000000           0.000000           0.000000
# 75%             0.000000           0.000000           0.000000
# max             1.000000           1.000000           1.000000
#
#        ind_deco_fin_ult1       ...         ind_hip_fin_ult1  \
# count      630244.000000       ...            630244.000000
# mean            0.002861       ...                 0.007489
# std             0.053410       ...                 0.086215
# min             0.000000       ...                 0.000000
# 25%             0.000000       ...                 0.000000
# 50%             0.000000       ...                 0.000000
# 75%             0.000000       ...                 0.000000
# max             1.000000       ...                 1.000000
#
#        ind_plan_fin_ult1  ind_pres_fin_ult1  ind_reca_fin_ult1  \
# count      630244.000000      630244.000000      630244.000000
# mean            0.011670           0.003237           0.065351
# std             0.107396           0.056801           0.247144
# min             0.000000           0.000000           0.000000
# 25%             0.000000           0.000000           0.000000
# 50%             0.000000           0.000000           0.000000
# 75%             0.000000           0.000000           0.000000
# max             1.000000           1.000000           1.000000
#
#        ind_tjcr_fin_ult1  ind_valo_fin_ult1  ind_viv_fin_ult1  \
# count      630244.000000      630244.000000     630244.000000
# mean            0.057992           0.031218          0.004979
# std             0.233728           0.173907          0.070386
# min             0.000000           0.000000          0.000000
# 25%             0.000000           0.000000          0.000000
# 50%             0.000000           0.000000          0.000000
# 75%             0.000000           0.000000          0.000000
# max             1.000000           1.000000          1.000000
#
#        ind_nomina_ult1  ind_nom_pens_ult1  ind_recibo_ult1
# count    630244.000000      630244.000000    630244.000000
# mean          0.069057           0.075688         0.156527
# std           0.253552           0.264499         0.363354
# min           0.000000           0.000000         0.000000
# 25%           0.000000           0.000000         0.000000
# 50%           0.000000           0.000000         0.000000
# 75%           0.000000           0.000000         0.000000
# max           1.000000           1.000000         1.000000
#
# [8 rows x 24 columns]

# %%
train_month_07[TARGET_LABELS].describe()
# Out:
#        ind_ahor_fin_ult1  ind_aval_fin_ult1  ind_cco_fin_ult1  \
# count      829811.000000      829811.000000     829811.000000
# mean            0.000099           0.000023          0.607246
# std             0.009940           0.004785          0.488363
# min             0.000000           0.000000          0.000000
# 25%             0.000000           0.000000          0.000000
# 50%             0.000000           0.000000          1.000000
# 75%             0.000000           0.000000          1.000000
# max             1.000000           1.000000          1.000000
#
#        ind_cder_fin_ult1  ind_cno_fin_ult1  ind_ctju_fin_ult1  \
# count      829811.000000     829811.000000      829811.000000
# mean            0.000386          0.074242           0.009137
# std             0.019634          0.262165           0.095150
# min             0.000000          0.000000           0.000000
# 25%             0.000000          0.000000           0.000000
# 50%             0.000000          0.000000           0.000000
# 75%             0.000000          0.000000           0.000000
# max             1.000000          1.000000           1.000000
#
#        ind_ctma_fin_ult1  ind_ctop_fin_ult1  ind_ctpp_fin_ult1  \
# count      829811.000000      829811.000000      829811.000000
# mean            0.008362           0.125677           0.042353
# std             0.091062           0.331485           0.201393
# min             0.000000           0.000000           0.000000
# 25%             0.000000           0.000000           0.000000
# 50%             0.000000           0.000000           0.000000
# 75%             0.000000           0.000000           0.000000
# max             1.000000           1.000000           1.000000
#
#        ind_deco_fin_ult1       ...         ind_hip_fin_ult1  \
# count      829811.000000       ...            829811.000000
# mean            0.002223       ...                 0.005671
# std             0.047100       ...                 0.075093
# min             0.000000       ...                 0.000000
# 25%             0.000000       ...                 0.000000
# 50%             0.000000       ...                 0.000000
# 75%             0.000000       ...                 0.000000
# max             1.000000       ...                 1.000000
#
#        ind_plan_fin_ult1  ind_pres_fin_ult1  ind_reca_fin_ult1  \
# count      829811.000000      829811.000000      829811.000000
# mean            0.008851           0.002439           0.050348
# std             0.093665           0.049327           0.218661
# min             0.000000           0.000000           0.000000
# 25%             0.000000           0.000000           0.000000
# 50%             0.000000           0.000000           0.000000
# 75%             0.000000           0.000000           0.000000
# max             1.000000           1.000000           1.000000
#
#        ind_tjcr_fin_ult1  ind_valo_fin_ult1  ind_viv_fin_ult1  \
# count      829811.000000      829811.000000     829811.000000
# mean            0.044780           0.023739          0.003770
# std             0.206821           0.152235          0.061281
# min             0.000000           0.000000          0.000000
# 25%             0.000000           0.000000          0.000000
# 50%             0.000000           0.000000          0.000000
# 75%             0.000000           0.000000          0.000000
# max             1.000000           1.000000          1.000000
#
#        ind_nomina_ult1  ind_nom_pens_ult1  ind_recibo_ult1
# count    829811.000000      829811.000000    829811.000000
# mean          0.054153           0.059759         0.120485
# std           0.226320           0.237041         0.325528
# min           0.000000           0.000000         0.000000
# 25%           0.000000           0.000000         0.000000
# 50%           0.000000           0.000000         0.000000
# 75%           0.000000           0.000000         0.000000
# max           1.000000           1.000000         1.000000
#
# [8 rows x 24 columns]
